# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_json(r"/home/mr_robot/datasets/noaa/solar/magnetic_field.json")

data
# Out:
#                     time_tag    x_gse   y_gse   z_gse
# 0    2026-06-01 14:00:00.000  1517964  255120  121182
# 1    2026-06-01 15:00:00.000  1517964  255120  121182
# 2    2026-06-01 16:00:00.000  1517964  255120  121182
# 3    2026-06-01 17:00:00.000  1517964  255120  121182
# 4    2026-06-01 18:00:00.000  1517964  255120  121182
# ..                       ...      ...     ...     ...
# 678  2026-06-29 20:00:00.000  1588122   82914    6378
# 679  2026-06-29 21:00:00.000  1588122   82914    6378
# 680  2026-06-29 22:00:00.000  1588122   82914    6378
# 681  2026-06-29 23:00:00.000  1588122   82914    6378
# 682  2026-06-30 00:00:00.000  1588122   82914    6378
#
# [683 rows x 4 columns]

# %%
data.info()
print(data.duplicated().sum())

print(data.isnull().sum())
# print(
#     data["DATA_STATUS_CODE"]
#     .isnull()
#     .mean()
# )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 1 to 683
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   time_tag  683 non-null    object
#  1   x_gse     683 non-null    object
#  2   y_gse     683 non-null    object
#  3   z_gse     683 non-null    object
#  4   vx_gse    0 non-null      object
#  5   vy_gse    0 non-null      object
#  6   vz_gse    0 non-null      object
#  7   x_gsm     0 non-null      object
#  8   y_gsm     0 non-null      object
#  9   z_gsm     0 non-null      object
#  10  vx_gsm    0 non-null      object
#  11  vy_gsm    0 non-null      object
#  12  vz_gsm    0 non-null      object
# dtypes: object(13)
# memory usage: 69.5+ KB
# 0
# 0
# time_tag    683
# x_gse       683
# y_gse       683
# z_gse       683
# vx_gse        0
# vy_gse        0
# vz_gse        0
# x_gsm         0
# y_gsm         0
# z_gsm         0
# vx_gsm        0
# vy_gsm        0
# vz_gsm        0
# ...

# %%
for col in data.columns:
    pct = (
        data[col].isnull().mean()
        * 100
    )
    print(col, round(pct, 2))
data
# Out:
# OBJECT_NAME 0.0
# OBJECT_ID 0.0
# NORAD_CAT_ID 0.0
# OBJECT_TYPE 0.0
# OPS_STATUS_CODE 0.0
# OWNER 0.0
# LAUNCH_DATE 0.0
# LAUNCH_SITE 0.0
# DECAY_DATE 0.0
# PERIOD 2.93
# INCLINATION 2.95
# APOGEE 2.93
# PERIGEE 2.93
# RCS 0.0
# ORBIT_CENTER 0.0
# ORBIT_TYPE 0.0
#         OBJECT_NAME   OBJECT_ID  NORAD_CAT_ID OBJECT_TYPE OPS_STATUS_CODE  \
# 0          SL-1 R/B   1957-001A             1         R/B               D
# 1         SPUTNIK 1   1957-001B             2         PAY               D
# 2         SPUTNIK 2   1957-002A             3         PAY               D
# 3        EXPLORER 1   1958-001A             4         PAY               D
# 4        VANGUARD 1   1958-002B             5         PAY         UNKNOWN
# ...             ...         ...           ...         ...             ...
# 69263       ISS DEB  1998-067YG         69324         DEB         UNKNOWN
# 69264   QIANFAN-163   2026-121A         69325         PAY               +
# ...

# %%
data["OPS_STATUS_CODE"] = (
    data["OPS_STATUS_CODE"]
    .fillna("UNKNOWN")
)
data["RCS"] = (
    data["RCS"]
    .fillna(-1)
)
data["DECAY_DATE"] = (
    data["DECAY_DATE"]
    .fillna("ACTIVE")
)

data.to_csv(
    "/home/mr_robot/datasets/celestrak/satcat/clean_satcat.csv",
    index=False
)

# %%
df=pd.read_csv(r)
# Out:
#         OBJECT_NAME   OBJECT_ID  NORAD_CAT_ID OBJECT_TYPE OPS_STATUS_CODE  \
# 0          SL-1 R/B   1957-001A             1         R/B               D
# 1         SPUTNIK 1   1957-001B             2         PAY               D
# 2         SPUTNIK 2   1957-002A             3         PAY               D
# 3        EXPLORER 1   1958-001A             4         PAY               D
# 4        VANGUARD 1   1958-002B             5         PAY         UNKNOWN
# ...             ...         ...           ...         ...             ...
# 69263       ISS DEB  1998-067YG         69324         DEB         UNKNOWN
# 69264   QIANFAN-163   2026-121A         69325         PAY               +
# 69265   QIANFAN-164   2026-121B         69326         PAY               +
# 69266    CZ-12B R/B   2026-121C         69327         R/B         UNKNOWN
# 69267  SZ-22 MODULE   2025-272C         69328         PAY               +
#
#       OWNER LAUNCH_DATE LAUNCH_SITE  DECAY_DATE  PERIOD  INCLINATION  APOGEE  \
# ...
